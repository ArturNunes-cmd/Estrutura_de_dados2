# %%
from collections import deque

fila = deque()

while True:
    arquivo = input("Digite o nome do arquivo ou 'sair' para encerrar: ")

    if arquivo.lower() == "sair":
        break

    fila.append(arquivo)

print("\nFila de impressão:")

while fila:
    arquivo = fila.popleft()
    print("Imprimindo:", arquivo)

print("Fila vazia.")
# Out:
# Digite o nome do arquivo ou 'sair' para encerrar: teste 1
# Digite o nome do arquivo ou 'sair' para encerrar: teste 2
# Digite o nome do arquivo ou 'sair' para encerrar: teste 3
# Digite o nome do arquivo ou 'sair' para encerrar: sair
#
# Fila de impressão:
# Imprimindo: teste 1
# Imprimindo: teste 2
# Imprimindo: teste 3
# Fila vazia.
